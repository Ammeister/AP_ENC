# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import textwrap

# %%
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_yticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width,
                      break_long_words=break_long_words))
    ax.set_yticklabels(labels, rotation=0)

# %%
df = pd.read_csv('histogramm_ech_1444.csv')
df = df.replace(['group_05', 'group_06', 'group_07', 'group_08', 'group_09', 'group_10', 'group_11', 'group_12', 
                'group_13', 'group_14', 'group_15', 'group_16', 'group_17', 'group_18', 'group_19', 'group_20', 
                'group_21', 'group_22', 'group_23', 'group_24', 'group_25', 'group_26', 'group_27', 'group_28', 
                'group_29', 'group_30', 'group_31', 'group_32'],
               ['marchands', 'boulangers', 'bouchers', 
                'tonneliers', 'drapiers', 'tanneurs', 
                'cabaretiers', 'maçons', 'forgerons', 
                'tailleurs', 'bateliers', 'pelletiers', 
                'charpentiers', 'crieurs et mesureurs de vin', 
                'cordonniers', 'orfèvres', 'marchands de grains', 
                'jardiniers', 'pêcheurs', 'barbiers et baigneurs', 
                'sauniers', 'tisserands', 'gourmets et courtiers', 
                'charrons', 'regrattiers, cordiers et fruitiers', 
                'coltineurs de tonneaux', 'constructeurs de bateaux', 
                'huiliers meuniers et tondeurs de draps'])
df = df.rename(columns={'represents_in':'corporation'})
df['effectif'] = df.groupby('corporation')['corporation'].transform('count')
df = df.drop_duplicates()

# %%
ordered_df = df.sort_values(by='effectif')
my_range=range(1,len(ordered_df.index)+1)
my_x = ordered_df['effectif'].to_list()

# %%
plt.figure(figsize=(10, 7), dpi=80)

plt.hlines(y=my_range, xmin=0, xmax=ordered_df['effectif'], color='b', alpha=0.4, label='d')
plt.scatter(ordered_df['effectif'], my_range, color='b', alpha=1)
plt.axvline(x=15, color='r', linestyle='-')

for i, txt in enumerate(ordered_df['effectif']):
    plt.annotate(txt, (my_x[i], my_range[i]))

plt.yticks(my_range, ordered_df['corporation'])
#plt.title("Nombre d'échevins par corporation par rapportà la limite fixée par le Conseil en 1433\nd'après la liste d'armement de 1444 (AVES AA 195)", loc='center')
plt.xlabel('Effectif')
plt.ylabel('Corporation')
plt.savefig('./Images/lolipop.png', transparent=True, dpi=80, bbox_inches='tight')

# %%
sorter_1444 = ["marchands", "boulangers", "bouchers", "tonneliers", "drapiers", "tanneurs", "cabaretiers",
               "maçons", "forgerons", "tailleurs", "bateliers", "pelletiers", "charpentiers",
               "crieurs et mesureurs de vin", "cordonniers", "orfèvres", "marchands de grains", "jardiniers",
               "pêcheurs", "barbiers et baigneurs", "sauniers", "tisserands", "gourmets et courtiers", "charrons",
               "regrattiers, cordiers et fruitiers", "coltineurs de tonneaux", "constructeurs de bateaux",
               "huiliers meuniers et tondeurs de draps"]
sorter_1444 = list(reversed(sorter_1444))

sorter_1463 = ["marchands", "boulangers", "bouchers", "tonneliers", "drapiers", "tanneurs", "cabaretiers",
               "maçons", "forgerons", "tailleurs", "bateliers", "pelletiers", "charpentiers",
               "crieurs et mesureurs de vin", "cordonniers", "orfèvres", "marchands de grains", "jardiniers",
               "pêcheurs", "barbiers et baigneurs", "sauniers", "tisserands", "gourmets et courtiers", "charrons",
               "regrattiers, cordiers et fruitiers", "huiliers meuniers et tondeurs de draps", 
               "coltineurs de tonneaux", "constructeurs de bateaux"]
sorter_1463 = list(reversed(sorter_1463))

sorter_1471 = ["bateliers", "marchands", "bouchers", "cabaretiers", "drapiers", "marchands de grains",
               "sauniers", "orfèvres", "boulangers", "pelletiers", "tonneliers", "tanneurs", "gourmets et courtiers",
               "tailleurs", "forgerons", "barbiers et baigneurs", "cordonniers", "pêcheurs", "charrons",
               "jardiniers", "tisserands", "regrattiers, cordiers et fruitiers", "charpentiers", "maçons",
               "crieurs et mesureurs de vin", "coltineurs de tonneaux", "constructeurs de bateaux",
               "huiliers meuniers et tondeurs de draps"]
sorter_1471 = list(reversed(sorter_1471))

sorter_1483 = ["bateliers", "marchands", "bouchers", "cabaretiers", "drapiers", "marchands de grains",
               "sauniers", "orfèvres", "boulangers", "pelletiers", "tonneliers", "tanneurs", "gourmets et courtiers",
               "tailleurs", "forgerons", "cordonniers", "pêcheurs", "charrons",
               "jardiniers", "maçons", "barbiers et baigneurs", "tisserands", "regrattiers, cordiers et fruitiers",
               "charpentiers", "crieurs et mesureurs de vin", "coltineurs de tonneaux", "constructeurs de bateaux",
               "huiliers meuniers et tondeurs de draps"]
sorter_1483 = list(reversed(sorter_1483))

sorter_nb = ["jardiniers", "tailleurs", "marchands", "bateliers", "pêcheurs", "cordonniers",
             "regrattiers, cordiers et fruitiers", "forgerons", "boulangers", "bouchers", "tonneliers",
             "orfèvres", "tisserands", "charrons", "barbiers et baigneurs", "cabaretiers",
             "maçons", "drapiers", "pelletiers", "coltineurs de tonneaux", "tanneurs",
             "huiliers meuniers et tondeurs de draps", "marchands de grains", "charpentiers",
             "gourmets et courtiers", "crieurs et mesureurs de vin", "constructeurs de bateaux", "sauniers"]
sorter_nb = list(reversed(sorter_nb))

# %%
df_1444 = ordered_df
df_1444.corporation = df_1444.corporation.astype("category")
df_1444.corporation.cat.set_categories(sorter_1444, inplace=True)
df_1444 = df_1444.sort_values(["corporation"])
my_range_1444=range(1,len(df_1444.index)+1)
my_x_1444 = df_1444['effectif'].to_list()

df_1463 = ordered_df
df_1463.corporation = df_1463.corporation.astype("category")
df_1463.corporation.cat.set_categories(sorter_1463, inplace=True)
df_1463 = df_1463.sort_values(["corporation"])
my_range_1463=range(1,len(df_1463.index)+1)
my_x_1463 = df_1463['effectif'].to_list()

df_1471 = ordered_df
df_1471.corporation = df_1471.corporation.astype("category")
df_1471.corporation.cat.set_categories(sorter_1471, inplace=True)
df_1471 = df_1471.sort_values(["corporation"])
my_range_1471=range(1,len(df_1471.index)+1)
my_x_1471 = df_1471['effectif'].to_list()

df_1483 = ordered_df
df_1483.corporation = df_1483.corporation.astype("category")
df_1483.corporation.cat.set_categories(sorter_1483, inplace=True)
df_1483 = df_1483.sort_values(["corporation"])
my_range_1483=range(1,len(df_1483.index)+1)
my_x_1483 = df_1483['effectif'].to_list()

df_nb = ordered_df
df_nb.corporation = df_nb.corporation.astype("category")
df_nb.corporation.cat.set_categories(sorter_nb, inplace=True)
df_nb = df_nb.sort_values(["corporation"])
my_range_nb=range(1,len(df_nb.index)+1)
my_x_nb = df_nb['effectif'].to_list()
# Out:
# /home/hippolyte/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/categorical.py:2631: FutureWarning: The `inplace` parameter in pandas.Categorical.set_categories is deprecated and will be removed in a future version. Removing unused categories will always return a new Categorical object.
#   res = method(*args, **kwargs)

# %%
fig, axs = plt.subplots(3, 1, sharex=True, sharey=False, figsize=(10, 30))

axs[0].hlines(y=my_range, xmin=0, xmax=ordered_df['effectif'], color='b', alpha=0.4, label='d')
axs[0].scatter(ordered_df['effectif'], my_range, color='b', alpha=1)
axs[0].axvline(x=15, color='r', linestyle='-')
for i, txt in enumerate(ordered_df['effectif']):
    axs[0].annotate(txt, (my_x[i], my_range[i]))
axs[0].set_yticks(my_range)
axs[0].set_yticklabels(ordered_df['corporation'])
axs[0].set_xlabel('Effectifs')
axs[0].set_ylabel('Corporation')
axs[0].title.set_text('Répartition des effectifs échevinaux par corporation (effectifs échevinaux décroissants en 1444)')

axs[1].hlines(y=my_range_1444, xmin=0, xmax=df_1444['effectif'], color='b', alpha=0.4, label='d')
axs[1].scatter(df_1444['effectif'], my_range_1444, color='b', alpha=1)
axs[1].axvline(x=15, color='r', linestyle='-')
for i, txt in enumerate(df_1444['effectif']):
    axs[1].annotate(txt, (my_x_1444[i], my_range_1444[i]))
axs[1].set_yticks(my_range_1444)
axs[1].set_yticklabels(df_1444['corporation'])
axs[1].set_xlabel('Effectifs')
axs[1].set_ylabel('Corporation')
axs[1].title.set_text('Répartition des effectifs échevinaux par corporation (hiérarchie au conseil en 1444)')

axs[2].hlines(y=my_range_nb, xmin=0, xmax=df_nb['effectif'], color='b', alpha=0.4, label='d')
axs[2].scatter(df_nb['effectif'], my_range_nb, color='b', alpha=1)
axs[2].axvline(x=15, color='r', linestyle='-')
for i, txt in enumerate(df_nb['effectif']):
    axs[2].annotate(txt, (my_x_nb[i], my_range_nb[i]))
axs[2].set_yticks(my_range_nb)
axs[2].set_yticklabels(df_nb['corporation'])
axs[2].set_xlabel('Effectifs')
axs[2].set_ylabel('Corporation')
axs[2].title.set_text('Répartition des effectifs échevinaux par corporation (effectifs totaux en 1444)')

#fig.savefig('./Images/3lolipop_1.svg', transparent=True, dpi=80, bbox_inches='tight')

# %%
fig, axs = plt.subplots(3, 1, sharex=True, sharey=False, figsize=(10, 30))

axs[0].hlines(y=my_range_1463, xmin=0, xmax=df_1463['effectif'], color='b', alpha=0.4, label='d')
axs[0].scatter(df_1463['effectif'], my_range_1463, color='b', alpha=1)
axs[0].axvline(x=15, color='r', linestyle='-')
for i, txt in enumerate(df_1463['effectif']):
    axs[0].annotate(txt, (my_x_1463[i], my_range_1463[i]))
axs[0].set_yticks(my_range_1463)
axs[0].set_yticklabels(df_1463['corporation'])
axs[0].set_xlabel('Effectifs')
axs[0].set_ylabel('Corporation')
axs[0].title.set_text('Répartition des effectifs échevinaux par corporation (hiérarchie au conseil en 1463)')

axs[1].hlines(y=my_range_1471, xmin=0, xmax=df_1471['effectif'], color='b', alpha=0.4, label='d')
axs[1].scatter(df_1471['effectif'], my_range_1471, color='b', alpha=1)
axs[1].axvline(x=15, color='r', linestyle='-')
for i, txt in enumerate(df_1471['effectif']):
    axs[1].annotate(txt, (my_x_1471[i], my_range_1471[i]))
axs[1].set_yticks(my_range_1471)
axs[1].set_yticklabels(df_1471['corporation'])
axs[1].set_xlabel('Effectifs')
axs[1].set_ylabel('Corporation')
axs[1].title.set_text('Répartition des effectifs échevinaux par corporation (hiérarchie au conseil en 1471)')

axs[2].hlines(y=my_range_1483, xmin=0, xmax=df_1483['effectif'], color='b', alpha=0.4, label='d')
axs[2].scatter(df_1483['effectif'], my_range_1483, color='b', alpha=1)
axs[2].axvline(x=15, color='r', linestyle='-')
for i, txt in enumerate(df_1483['effectif']):
    axs[2].annotate(txt, (my_x_1483[i], my_range_1483[i]))
axs[2].set_yticks(my_range_1483)
axs[2].set_yticklabels(df_1483['corporation'])
axs[2].set_xlabel('Effectifs')
axs[2].set_ylabel('Corporation')
axs[2].title.set_text('Répartition des effectifs échevinaux par corporation (hiérarchie au conseil en 1483)')

#fig.savefig('./Images/3lolipop_2.svg', transparent=True, dpi=80, bbox_inches='tight')

# %%
total = [690, 293, 265, 262, 234, 222, 172, 163, 160, 152, 145, 142, 142, 131, 120, 118, 114, 101, 93, 78, 77,
         74, 69, 67, 65, 63, 36, 35]
total = list(reversed(total))

df_nb['total'] = total

# %%
ax = df_nb.plot(x="corporation", y="total", kind="barh", color = 'orange', figsize = (7,8))
df_nb.plot(x="corporation", y="effectif", kind="barh", ax=ax)

#plt.savefig('./Images/stackedbar_effectif_total.svg', transparent=True, dpi=80, bbox_inches='tight')

# %%
df = pd.read_csv('./../04-social_network_analysis/preprocessing/occurrences.csv')
df = df.replace(['group_05', 'group_06', 'group_07', 'group_08', 'group_09', 'group_10', 'group_11', 'group_12', 
                'group_13', 'group_14', 'group_15', 'group_16', 'group_17', 'group_18', 'group_19', 'group_20', 
                'group_21', 'group_22', 'group_23', 'group_24', 'group_25', 'group_26', 'group_27', 'group_28', 
                'group_29', 'group_30', 'group_31', 'group_32'],
               ['marchands', 'boulangers', 'bouchers', 
                'tonneliers', 'drapiers', 'tanneurs', 
                'cabaretiers', 'maçons', 'forgerons', 
                'tailleurs', 'bateliers', 'pelletiers', 
                'charpentiers', 'crieurs et mesureurs de vin', 
                'cordonniers', 'orfèvres', 'marchands de grains', 
                'jardiniers', 'pêcheurs', 'barbiers et baigneurs', 
                'sauniers', 'tisserands', 'gourmets et courtiers', 
                'charrons', 'regrattiers, cordiers et fruitiers', 
                'coltineurs de tonneaux', 'constructeurs de bateaux', 
                'huiliers meuniers et tondeurs de draps'])
df = df.loc[df['role'] == 'group_49']

# %%
dic = {}
for element in ['jardiniers', 'tanneurs', 'drapiers', 'marchands', 'sauniers', 'tailleurs', 'gourmets et courtiers', 
                'pelletiers', 'tisserands', 'cabaretiers', 'cordonniers', 'forgerons', 'bateliers', 'maçons', 
                'orfèvres', 'pêcheurs', 'regrattiers, cordiers et fruitiers', 'barbiers et baigneurs', 
                'huiliers meuniers et tondeurs de draps', 'crieurs et mesureurs de vin', 'charrons', 
                'marchands de grains', 'coltineurs de tonneaux', 'charpentiers', 'constructeurs de bateaux', 
                'tonneliers', 'bouchers', 'boulangers']:

    sub_df = df.loc[df['represents'] == element]
    n = sub_df['authority'].nunique()
    dic[element] = n

# %%
df_out = pd.DataFrame.from_dict(dic.items())

# %%
df_out = df_out.rename(columns={0: "corporation", 1 : "effectif"})

# %%
plt.figure(figsize=(10,7))
ax = sns.barplot(x="effectif", y="corporation", data= df_out, )
plt.savefig('./Images/bar_effectif_conseiller.svg', transparent=True, dpi=80, bbox_inches='tight')
